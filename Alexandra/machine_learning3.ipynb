# %% [markdown]
# # Machine Learning on top 6 measurements
# ## Missing data is filled in with mean values of each column

# %%
import pandas as pd

# %%
neuro = pd.read_csv("all_neuron_data.csv")

# %%
# Jacob saturday
# Filter down our dataset to only use top 6 measurements
neuro_filtered = neuro.loc[(neuro["Measurement"] == "input resistance") |
                          (neuro["Measurement"] == "resting membrane potential") |
                          (neuro["Measurement"] == "spike threshold") |
                          (neuro["Measurement"] == "spike half-width") |
                          (neuro["Measurement"] == "spike amplitude") |
                          (neuro["Measurement"] == "membrane time constant")]

neuro_filtered
# Out:
#                                                Cell Type   Value  \
# 0                              Dorsal root ganglion cell  -54.30
# 1                              Dorsal root ganglion cell  -27.40
# 2                              Dorsal root ganglion cell  101.30
# 5                              Dorsal root ganglion cell  192.00
# 7      Spinal cord intermediate horn motor neuron sym...  -59.80
# 8      Spinal cord intermediate horn motor neuron sym...    1.14
# 9      Spinal cord intermediate horn motor neuron sym...   92.40
# 11     Spinal cord intermediate horn motor neuron sym...   57.10
# 13     Spinal cord intermediate horn motor neuron sym...  -45.30
# 18                        Hippocampus CA1 pyramidal cell  -51.50
# 19                        Hippocampus CA1 pyramidal cell    1.60
# 21                        Hippocampus CA1 pyramidal cell   27.90
# 22                        Hippocampus CA1 pyramidal cell  -64.80
# 23                        Hippocampus CA1 pyramidal cell  100.60
# 26                               Cerebellar nucleus cell  -68.58
# 28                               Cerebellar nucleus cell    2.13
# 30                               Cerebellar nucleus cell   59.26
# 32                               Cerebellar nucleus cell  -58.84
# 34                        Hippocampus CA3 pyramidal cell  164.00
# 35                        Hippocampus CA3 pyramidal cell   61.00
# 37                        Hippocampus CA3 pyramidal cell  -76.00
# 38                        Hippocampus CA3 pyramidal cell  -58.00
# 39                        Hippocampus CA3 pyramidal cell    0.79
# 43                    Basalis nucleus cholinergic neuron  -48.00
# 44                    Basalis nucleus cholinergic neuron  268.00
# 45                    Basalis nucleus cholinergic neuron   28.20
# 48                    Basalis nucleus cholinergic neuron  -31.90
# 49                    Basalis nucleus cholinergic neuron    0.52
# 51                    Basalis nucleus cholinergic neuron   66.70
# 53                                 Neocortex basket cell   87.00
# ...                                                  ...     ...
# 16630              Cochlear nucleus (ventral) bushy cell    1.40
# 16631       Cochlear nucleus (ventral) multipolar T cell  -64.10
# 16632       Cochlear nucleus (ventral) multipolar T cell    6.80
# 16633              Cochlear nucleus (ventral) bushy cell  -64.40
# 16634              Cochlear nucleus (ventral) bushy cell  -63.00
# 16635            Cochlear nucleus (ventral) octopus cell    0.30
# 16636            Cochlear nucleus (ventral) octopus cell    0.20
# 16637              Cochlear nucleus (ventral) bushy cell   68.00
# 16638              Cochlear nucleus (ventral) bushy cell   67.00
# 16639       Cochlear nucleus (ventral) multipolar T cell    6.00
# 16640       Cochlear nucleus (ventral) multipolar T cell  126.00
# 16641       Cochlear nucleus (ventral) multipolar T cell   74.00
# 16642                           Cerebellum Purkinje cell   23.30
# 16643                           Cerebellum Purkinje cell    0.15
# 16647                     Hippocampus CA1 pyramidal cell    3.60
# 16649                 Neocortex pyramidal cell layer 2-3   56.00
# 16653                 Neocortex pyramidal cell layer 2-3    1.20
# 16656                     Globus pallidus principal cell  -58.10
# 16657                     Globus pallidus principal cell  311.50
# 16658                     Globus pallidus principal cell   78.80
# 16660                     Globus pallidus principal cell   70.00
# 16662                     Globus pallidus principal cell   19.90
# 16664                     Globus pallidus principal cell  698.20
# 16666                     Globus pallidus principal cell  -66.60
# 16667                     Globus pallidus principal cell  -42.90
# 16668                     Globus pallidus principal cell  -42.50
# 16669                     Globus pallidus principal cell   36.30
# 16670                    Neostriatum medium spiny neuron   35.90
# 16671                 Neocortex pyramidal cell layer 5-6   12.00
# 16674                     Neocortex uncharacterized cell   13.00
#
#                       Measurement
# 0      resting membrane potential
# 1                 spike threshold
# 2                 spike amplitude
# 5                input resistance
# 7      resting membrane potential
# 8                input resistance
# 9          membrane time constant
# 11                spike amplitude
# 13                spike threshold
# 18                spike threshold
# 19               spike half-width
# 21         membrane time constant
# 22     resting membrane potential
# 23               input resistance
# 26                spike threshold
# 28               spike half-width
# 30               input resistance
# 32     resting membrane potential
# 34               input resistance
# 35         membrane time constant
# 37     resting membrane potential
# 38                spike threshold
# 39               spike half-width
# 43     resting membrane potential
# 44               input resistance
# 45         membrane time constant
# 48                spike threshold
# 49               spike half-width
# 51                spike amplitude
# 53                spike amplitude
# ...                           ...
# 16630      membrane time constant
# 16631  resting membrane potential
# 16632      membrane time constant
# 16633  resting membrane potential
# 16634  resting membrane potential
# 16635      membrane time constant
# 16636      membrane time constant
# 16637            input resistance
# 16638            input resistance
# 16639      membrane time constant
# 16640            input resistance
# 16641            input resistance
# 16642            input resistance
# 16643            spike half-width
# 16647            spike half-width
# 16649            input resistance
# 16653            spike half-width
# 16656  resting membrane potential
# 16657            input resistance
# 16658             spike amplitude
# 16660             spike amplitude
# 16662      membrane time constant
# 16664            input resistance
# 16666  resting membrane potential
# 16667             spike threshold
# 16668             spike threshold
# 16669      membrane time constant
# 16670            input resistance
# 16671      membrane time constant
# 16674      membrane time constant
#
# [9506 rows x 3 columns]

# %%
current_cell = ""
current_dict = {}
big_list = []

for index, row in neuro_filtered.iterrows():
    if current_cell != row["Cell Type"]:
        # if the current cell and next cell are different, make a new empty row
        big_list.append(current_dict)
        current_dict = {}
        current_cell = row["Cell Type"]
        current_dict["Cell Type"] = current_cell
        current_dict[row["Measurement"]] = row["Value"]
    else:
        # else add the measurement value into the appropriate measurement column
        current_dict[row["Measurement"]] = row["Value"]

del big_list[0]
print(big_list)
# Out:
# [{'Cell Type': 'Dorsal root ganglion cell', 'resting membrane potential': -54.3, 'spike threshold': -27.4, 'spike amplitude': 101.3, 'input resistance': 192.0}, {'Cell Type': 'Spinal cord intermediate horn motor neuron sympathetic', 'resting membrane potential': -59.8, 'input resistance': 1.14, 'membrane time constant': 92.4, 'spike amplitude': 57.1, 'spike threshold': -45.3}, {'Cell Type': 'Hippocampus CA1 pyramidal cell', 'spike threshold': -51.5, 'spike half-width': 1.6, 'membrane time constant': 27.9, 'resting membrane potential': -64.8, 'input resistance': 100.6}, {'Cell Type': 'Cerebellar nucleus cell', 'spike threshold': -68.58, 'spike half-width': 2.13, 'input resistance': 59.26, 'resting membrane potential': -58.84}, {'Cell Type': 'Hippocampus CA3 pyramidal cell', 'input resistance': 164.0, 'membrane time constant': 61.0, 'resting membrane potential': -76.0, 'spike threshold': -58.0, 'spike half-width': 0.79}, {'Cell Type': 'Basalis nucleus cholinergic neuron', 'resting membrane potential': -48.0, 'input resistance': 268.0, 'membrane time constant': 28.2, 'spike threshold': -31.9, 'spike half-width': 0.52, 'spike amplitude': 66.7}, {'Cell Type': 'Neocortex basket cell', 'spike amplitude': 87.0, 'spike threshold': -40.0, 'membrane time constant': 4.8, 'input resistance': 142.0, 'resting membrane potential': -59.0, 'spike half-width': 0.3}, {'Cell Type': 'Spinal cord ventral horn motor neuron alpha', 'resting membrane potential': -55.0, 'input resistance': 11.1, 'membrane time constant': 4.9}, {'Cell Type': 'Neocortex basket cell', 'resting membrane potential': -67.0, 'spike threshold': -34.0, 'spike amplitude': 52.0, 'spike half-width': 0.38, 'input resistance': 182.0, 'membrane time constant': 7.7}, {'Cell Type': 'Dorsal root ganglion cell', 'resting membrane potential': -59.0, 'input resistance': 392.0, 'membrane time constant': 27.0, 'spike threshold': -36.0, 'spike amplitude': 105.0}, {'Cell Type': 'Neocortex pyramidal cell layer 5-6', 'spike threshold': -42.56, 'membrane time constant': 11.43, 'input resistance': 23.31, 'resting membrane potential': -72.69, 'spike amplitude': 87.46, 'spike half-width': 0.63}, {'Cell Type': 'Neostriatum medium spiny neuron', 'resting membrane potential': -83.5, 'input resistance': 139.0, 'spike amplitude': 74.8, 'spike threshold': -33.9, 'spike half-width': 1.04}, {'Cell Type': 'Dorsal root ganglion cell', 'resting membrane potential': -60.5, 'spike threshold': -29.6, 'spike amplitude': 100.2, 'input resistance': 225.0}, {'Cell Type': 'Neocortex basket cell', 'input resistance': 163.92, 'spike half-width': 0.46, 'spike threshold': -30.57, 'resting membrane potential': -67.88, 'membrane time constant': 11.83}, {'Cell Type': 'Neostriatum medium spiny neuron', 'resting membrane potential': -81.0, 'membrane time constant': 15.6, 'spike threshold': -43.9, 'spike amplitude': 64.3, 'spike half-width': 0.85}, {'Cell Type': 'Cerebellar nucleus cell', 'input resistance': 0.61, 'membrane time constant': 74.6, 'spike half-width': 1.44, 'spike amplitude': 66.43}, {'Cell Type': 'Amygdaloid nucleus paracapsular intercalated cell', 'input resistance': 270.0, 'membrane time constant': 22.0, 'spike amplitude': 82.0}, {'Cell Type': 'Neocortex pyramidal cell layer 5-6', 'input resistance': 363.4, 'membrane time constant': 9.09, 'spike threshold': -40.7, 'spike amplitude': 85.9, 'spike half-width': 1.58, 'resting membrane potential': -71.2}, {'Cell Type': 'Spinal cord ventral horn interneuron V2', 'resting membrane potential': -47.0, 'input resistance': 1590.0, 'membrane time constant': 55.0, 'spike amplitude': 53.0, 'spike threshold': -42.0}, {'Cell Type': 'Hippocampus CA1 pyramidal cell', 'resting membrane potential': -69.9, 'input resistance': 35.4, 'spike threshold': -58.9, 'spike amplitude': 92.0, 'spike half-width': 0.83}, {'Cell Type': 'Neostriatum medium spiny neuron', 'input resistance': 670.0, 'spike amplitude': 40.4, 'spike threshold': -37.7, 'resting membrane potential': -72.0}, {'Cell Type ...

# %%
# Saturday
cleaned = pd.DataFrame(big_list)

mean_input_resist = cleaned["input resistance"].mean()
mean_mem_const = cleaned["membrane time constant"].mean()
mean_resting_mem = cleaned["resting membrane potential"].mean()
mean_spike_amp = cleaned["spike amplitude"].mean()
mean_spike_half = cleaned["spike half-width"].mean()
mean_spike_thresh = cleaned["spike threshold"].mean()

cleaned["input resistance"].fillna(mean_input_resist, inplace=True)
cleaned["membrane time constant"].fillna(mean_mem_const, inplace=True)
cleaned["resting membrane potential"].fillna(mean_resting_mem, inplace=True)
cleaned["spike amplitude"].fillna(mean_spike_amp, inplace=True)
cleaned["spike half-width"].fillna(mean_spike_half, inplace=True)
cleaned["spike threshold"].fillna(mean_spike_thresh, inplace=True)

cleaned
# Out:
#                                               Cell Type  input resistance  \
# 0                             Dorsal root ganglion cell        192.000000
# 1     Spinal cord intermediate horn motor neuron sym...          1.140000
# 2                        Hippocampus CA1 pyramidal cell        100.600000
# 3                               Cerebellar nucleus cell         59.260000
# 4                        Hippocampus CA3 pyramidal cell        164.000000
# 5                    Basalis nucleus cholinergic neuron        268.000000
# 6                                 Neocortex basket cell        142.000000
# 7           Spinal cord ventral horn motor neuron alpha         11.100000
# 8                                 Neocortex basket cell        182.000000
# 9                             Dorsal root ganglion cell        392.000000
# 10                   Neocortex pyramidal cell layer 5-6         23.310000
# 11                      Neostriatum medium spiny neuron        139.000000
# 12                            Dorsal root ganglion cell        225.000000
# 13                                Neocortex basket cell        163.920000
# 14                      Neostriatum medium spiny neuron        220.789879
# 15                              Cerebellar nucleus cell          0.610000
# 16    Amygdaloid nucleus paracapsular intercalated cell        270.000000
# 17                   Neocortex pyramidal cell layer 5-6        363.400000
# 18              Spinal cord ventral horn interneuron V2       1590.000000
# 19                       Hippocampus CA1 pyramidal cell         35.400000
# 20                      Neostriatum medium spiny neuron        670.000000
# 21                       Suprachiasmatic nucleus neuron          1.290000
# 22                           Dentate gyrus granule cell        351.300000
# 23                            Neocortex Martinotti cell        220.789879
# 24                       Hippocampus CA1 pyramidal cell         42.050000
# 25                   Neocortex pyramidal cell layer 2-3        220.789879
# 26                                                Other        456.900000
# 27                      Thalamic reticular nucleus cell        273.800000
# 28                      Neostriatum medium spiny neuron        383.000000
# 29    Amygdaloid nucleus paracapsular intercalated cell        705.000000
# ...                                                 ...               ...
# 2078                                              Other         98.000000
# 2079                    Thalamic reticular nucleus cell        220.789879
# 2080        Spinal cord ventral horn motor neuron alpha          5.100000
# 2081                          Dorsal root ganglion cell        220.789879
# 2082   Substantia nigra pars compacta dopaminergic cell        181.500000
# 2083      Amygdala basolateral nucleus pyramidal neuron        238.400000
# 2084                                Thalamus relay cell        220.789879
# 2085                    Neostriatum medium spiny neuron        246.000000
# 2086                           Cerebellum Purkinje cell          0.140000
# 2087       Nucleus of the solitary tract principal cell          1.300000
# 2088                                              Other        791.000000
# 2089                   Hypoglossal nucleus motor neuron        137.710000
# 2090                           Cerebellum Purkinje cell        220.789879
# 2091                                              Other          1.300000
# 2092                 Neocortex pyramidal cell layer 2-3        326.000000
# 2093                                              Other         56.000000
# 2094            Cochlear nucleus (ventral) octopus cell         14.000000
# 2095       Cochlear nucleus (ventral) multipolar T cell        220.789879
# 2096              Cochlear nucleus (ventral) bushy cell        220.789879
# 2097       Cochlear nucleus (ventral) multipolar T cell        220.789879
# 2098              Cochlear nucleus (ventral) bushy cell        220.789879
# 2099            Cochlear nucleus (ventral) octopus cell        220.789879
# 2100              Cochlear nucleus (ventral) bushy cell         67.000000
# 2101       Cochlear nucleus (ventral) multipolar T cell         74.000000
# 2102                           Cerebellum Purkinje cell         23.300000
# 2103                     Hippocampus CA1 pyramidal cell        220.789879
# 2104                 Neocortex pyramidal cell layer 2-3         56.000000
# 2105                     Globus pallidus principal cell        698.200000
# 2106                    Neostriatum medium spiny neuron         35.900000
# 2107                 Neocortex pyramidal cell layer 5-6        220.789879
#
#       membrane time constant  resting membrane potential  spike amplitude  \
# 0                  22.980182                  -54.300000       101.300000
# 1                  92.400000                  -59.800000        57.100000
# 2                  27.900000                  -64.800000        72.142382
# 3                  22.980182                  -58.840000        72.142382
# 4                  61.000000                  -76.000000        72.142382
# 5                  28.200000                  -48.000000        66.700000
# 6                   4.800000                  -59.000000        87.000000
# 7                   4.900000                  -55.000000        72.142382
# 8                   7.700000                  -67.000000        52.000000
# 9                  27.000000                  -59.000000       105.000000
# 10                 11.430000                  -72.690000        87.460000
# 11                 22.980182                  -83.500000        74.800000
# 12                 22.980182                  -60.500000       100.200000
# 13                 11.830000                  -67.880000        72.142382
# 14                 15.600000                  -81.000000        64.300000
# 15                 74.600000                  -60.839158        66.430000
# 16                 22.000000                  -60.839158        82.000000
# 17                  9.090000                  -71.200000        85.900000
# 18                 55.000000                  -47.000000        53.000000
# 19                 22.980182                  -69.900000        92.000000
# 20                 22.980182                  -72.000000        40.400000
# 21                 28.600000                  -56.000000        72.142382
# 22                 22.980182                  -73.800000        72.142382
# 23                 36.400000                  -54.500000        64.000000
# 24                 26.360000                  -57.330000        72.142382
# 25                 16.000000                  -78.560000        67.800000
# 26                 19.000000                  -67.000000        72.142382
# 27                 22.980182                  -75.900000        67.400000
# 28                 22.980182                  -74.000000        42.400000
# 29                 21.650000                  -60.839158        82.330000
# ...                      ...                         ...              ...
# 2078               22.980182                  -65.000000        81.500000
# 2079               22.980182                  -60.839158        80.800000
# 2080                3.600000                  -66.000000        75.000000
# 2081               22.980182                  -60.839158       116.900000
# 2082               22.980182                  -60.839158        72.142382
# 2083               59.100000                  -60.839158        72.142382
# 2084               22.980182                  -61.600000        65.200000
# 2085               22.980182                  -77.800000        40.400000
# 2086               22.980182                  -60.839158        72.142382
# 2087               55.000000                  -52.000000        43.000000
# 2088               61.000000                  -54.000000        73.000000
# 2089               22.980182                  -56.810000        72.142382
# 2090               22.980182                  -60.839158        72.142382
# 2091               22.980182                  -47.900000        77.100000
# 2092               76.800000                  -78.900000        72.142382
# 2093               15.000000                  -67.000000        72.142382
# 2094               22.980182                  -62.000000        72.142382
# 2095               22.980182                  -64.000000        72.142382
# 2096                1.400000                  -60.839158        72.142382
# 2097                6.800000                  -64.100000        72.142382
# 2098               22.980182                  -63.000000        72.142382
# 2099                0.200000                  -60.839158        72.142382
# 2100               22.980182                  -60.839158        72.142382
# 2101                6.000000                  -60.839158        72.142382
# 2102               22.980182                  -60.839158        72.142382
# 2103               22.980182                  -60.839158        72.142382
# 2104               22.980182                  -60.839158        72.142382
# 2105               36.300000                  -66.600000        70.000000
# 2106               22.980182                  -60.839158        72.142382
# 2107               12.000000                  -60.839158        72.142382
#
#       spike half-width  spike threshold
# 0             8.531983       -27.400000
# 1             8.531983       -45.300000
# 2             1.600000       -51.500000
# 3             2.130000       -68.580000
# 4             0.790000       -58.000000
# 5             0.520000       -31.900000
# 6             0.300000       -40.000000
# 7             8.531983       -34.683831
# 8             0.380000       -34.000000
# 9             8.531983       -36.000000
# 10            0.630000       -42.560000
# 11            1.040000       -33.900000
# 12            8.531983       -29.600000
# 13            0.460000       -30.570000
# 14            0.850000       -43.900000
# 15            1.440000       -34.683831
# 16            8.531983       -34.683831
# 17            1.580000       -40.700000
# 18            8.531983       -42.000000
# 19            0.830000       -58.900000
# 20            8.531983       -37.700000
# 21            1.510000       -40.600000
# 22            1.550000       -37.300000
# 23            1.980000       -34.683831
# 24            8.531983       -35.850000
# 25            1.420000       -37.700000
# 26            1.110000       -39.300000
# 27            0.190000       -47.500000
# 28            1.300000       -34.500000
# 29            8.531983       -34.683831
# ...                ...              ...
# 2078          2.700000       -34.683831
# 2079          0.460000       -50.900000
# 2080          0.320000       -50.000000
# 2081          1.900000       -27.000000
# 2082          8.531983       -34.683831
# 2083          1.390000       -41.300000
# 2084          8.531983       -34.683831
# 2085          8.531983       -37.700000
# 2086          8.531983       -34.683831
# 2087          3.000000       -38.000000
# 2088          1.430000       -37.000000
# 2089          8.531983       -34.683831
# 2090          0.230000       -34.683831
# 2091          1.900000       -52.600000
# 2092          8.531983       -49.300000
# 2093          8.531983       -34.683831
# 2094          8.531983       -34.683831
# 2095          8.531983       -34.683831
# 2096          8.531983       -34.683831
# 2097          8.531983       -34.683831
# 2098          8.531983       -34.683831
# 2099          8.531983       -34.683831
# 2100          8.531983       -34.683831
# 2101          8.531983       -34.683831
# 2102          0.150000       -34.683831
# 2103          3.600000       -34.683831
# 2104          1.200000       -34.683831
# 2105          8.531983       -42.500000
# 2106          8.531983       -34.683831
# 2107          8.531983       -34.683831
#
# [2108 rows x 7 columns]

# %%
# Run machine learning on this narrowed down dataset
X=cleaned.drop("Cell Type", axis=1)
y=cleaned["Cell Type"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=42)

# %% [markdown]
# ### Random forest model

# %%
from sklearn.ensemble import RandomForestClassifier
#cls = classifier
cls= RandomForestClassifier(n_estimators=500)
cls.fit(x_train, y_train)
y_predict = cls.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
# how many right divided by the total
print(accuracy_score(y_test, y_predict))
# Out:
# 0.168246445498

# %% [markdown]
# ### Deep learning model

# %%
# Machine learning model will not work on data categories with only 1 row
# dropping all rows that have fewer than 5 data points associated with a category

counts = cleaned['Cell Type'].value_counts()
greater_than_10 = cleaned[cleaned['Cell Type'].isin(counts[counts >= 10].index)]

# Run machine learning on this narrowed down dataset
X=greater_than_10.drop("Cell Type", axis=1)
y=greater_than_10["Cell Type"]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

# This code works in machine_learning2 notebook but not here. y is the same.  How come?
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Filter data, run machine learning on filtered data

# %%
words = ["CA1", "CA3"]
for i, row in cleaned.iterrows():
    if any(word in row["Cell Type"] for word in words):
#         print("true")0
        cleaned.loc[i, "Area"] = "Hippocampus"
#         row["Area"] = "Hippocampus"
    else:
        cleaned.loc[i, "Area"] = "other"
        row["Area"] = "other"

# %%
hippo_df = cleaned.loc[cleaned["Area"] == "Hippocampus"]
X=hippo_df.drop(["Cell Type", "Area"], axis=1)
y=hippo_df["Cell Type"]

# %%
print(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

y=y.tolist()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
y_train

# %%
y_train_categorical
